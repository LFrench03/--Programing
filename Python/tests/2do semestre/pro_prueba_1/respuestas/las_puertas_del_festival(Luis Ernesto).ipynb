# %% [markdown]
# ## A las puertas del festival

# %% [markdown]
# Bienvenido aventurero, veo que has llegado a las puertas de nuestro festival, lamentablemente las entradas se nos han agotado, asi que creo que no podras entrar, a no ser que... nah... no creo que seas capas... bueno, si logras resolverme este puzzle chino otakudeso de aca quizas pueda hacer una excepcion y dejarte entrar, llevo semanas intentandolo y nada.

# %% [markdown]
# El portero se acerca a ti y te entrega una hoja con los siguientes numeros:
#
# ![image.png](attachment:image.png)
#
# -Segun tengo entendido hay que rellenar todas las casillas con numeros del 1 al 9 de tal manera que en ninguna fila o columna se repita un numero y que en una region de 3x3 tampoco se puede repetir ninguno, ayudame con esto y con gusto te dejare entrar (pero no le digas a tus amigos que mi jefe me va a despedir si se entera)

# %% [markdown]
# la ultima fila del sudoku es la contraseña para descomprimir la prueba real :D

# %%
def print_grid(arr):
    for i in range(9):
        for j in range(9):
            print(arr[i][j], end=" ")
        print()
 
def find_empty_location(arr, l):
    for row in range(9):
        for col in range(9):
            if(arr[row][col] == 0):
                l[0]= row
                l[1]= col
                return True
    return False
 
def used_in_row(arr, row, num):
    for i in range(9):
        if(arr[row][i] == num):
            return True
    return False
def used_in_col(arr, col, num):
    for i in range(9):
        if(arr[i][col] == num):
            return True
    return False
 
def used_in_box(arr, row, col, num):
    for i in range(3):
        for j in range(3):
            if(arr[i + row][j + col] == num):
                return True
    return False
 
def check_location_is_safe(arr, row, col, num):
    return not used_in_row(arr, row, num) and not used_in_col(arr, col, num) and not used_in_box(arr, row - row % 3, col - col % 3, num)
 
def solve_sudoku(arr):

    l =[0, 0]
 
    if(not find_empty_location(arr, l)):
        return True
    row = l[0]
    col = l[1]
    
    for num in range(1, 10):
        if(check_location_is_safe(arr, row, col, num)):
            arr[row][col]= num

            if(solve_sudoku(arr)):
                return True
            
            arr[row][col] = 0     
    return False
if __name__=="__main__":
    grid =[[0 for x in range(9)]for y in range(9)]
    grid = [[5,3,0,0,7,0,0,0,0],
            [6,0,0,1,9,5,0,0,0],
            [0,9,8,0,0,0,0,6,0],
            [8,0,0,0,6,0,0,0,3],
            [4,0,0,8,0,3,0,0,1],
            [7,0,0,0,2,0,0,0,6],
            [0,6,0,0,0,0,2,8,0],
            [0,0,0,4,1,9,0,0,5],
            [0,0,0,0,8,0,0,7,9]]
     
    if(solve_sudoku(grid)):
        print_grid(grid)
    else:
        print("No solution exists")
# Out:
# 5 3 4 6 7 8 9 1 2
# 6 7 2 1 9 5 3 4 8
# 1 9 8 3 4 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 6 8 5 3 7 9 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 4 5 2 8 6 1 7 9
