# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Se utiliza lee el archivo .csv con ```pd.read_csv``` introduciendo ademas los parametros ```index_col=0``` (para que la columna de los indices se establezca para los datetime, y ```parse_dates=True``` (para las etiquetas de los indices se muestren visibles de forma diagonal)).

# %% [markdown]
# Utilizamos el metodo ``.plot()`` para mostrar un grafico de frecuencia de las columnas que introduzcamos como argumento

# %%
air_quality = pd.read_csv("data/air_quality_no2.csv", index_col=0, parse_dates=True)

air_quality.plot()
plt.show()

# %%
air_quality = pd.read_csv("data/air_quality_no2.csv", index_col=0, parse_dates=True)

air_quality["station_paris"].plot()#Solo las observaciones para paris
plt.show()

# %%
air_quality.plot.scatter(x = "station_london", y = "station_paris", alpha = 0.5)
plt.show()

# %%
air_quality.plot.box()
plt.show()

# %%
fig = plt.figure()             # an empty figure with no Axes
fig, ax = plt.subplots()       # a figure with a single Axes
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes
# a figure with one Axes on the left, and two on the right:
fig, axs = plt.subplot_mosaic([['left', 'right_top'],
                               ['left', 'right_bottom']])

# %%
#Parametros:
m = [".", ",","o","v","^","<",">","1","2","3","4","s","p","*","h","H","+","x","D","d","|","_"]
ms= [5,10,15,20,25,30,40]
ls = ["-","--","-.",":","None"]
alpha = [0.10, 0.25, 0.50, 0.75, 1]
lw = [1,2,3]
def line(x,y,p1,p2,p3,p4,p5,p6,p7,p8):
    #import matplotlib.pyplot as plt
    #import numpy as np
    plt.title(input("Introduzca el title: "))
    plt.xlabel(input("Introduzca la etiqueta del xlabel: "))
    plt.ylabel(input("Intoruzca la etiqueta del ylabel: "))
    orderx = bool(input("Seleccione el orden de los valores de x para reverse = True or reverse = False: "))
    while orderx != True and orderx != False:
        orderx = bool(input("Valor no booleano, seleccione el orden de los valores de x para reverse = True or reverse = False: "))
    ordery = bool(input("Seleccione el orden de los valores de y para reverse = True or reverse = False: "))
    while ordery != True and ordery != False:
        ordery = bool(input("Valor no booleano, seleccione el orden de los valores de y para reverse = True or reverse = False: "))
    out = plt.plot(sorted(list(x),reverse = orderx),sorted(list(y),reverse= ordery),marker = p1, ls =p2, c = p3, lw = p4, alpha = p5, ms = p6, mec = p7, mfc = p8)
    return out
from numpy import random
x = random.randint(1,20,size=5)
y = random.randint(1,20,size=5)
line(x,y,m[0],ls[0],"blue",lw[1],alpha[2],ms[3],"k","red")
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
